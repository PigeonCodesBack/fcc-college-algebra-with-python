# %% [markdown]
# # Ratios and Proportions: Extra

# %% [markdown]
# # Resources
#
# The last video in this section will show you how to use proportions in other applications, such as currency exchange rates and unit conversion. It will also show you more about setting up your notebook and working through the practice assignment.

# %% [markdown]
# ## [Video](https://youtu.be/6o0SsdyUf2U)

# %% [markdown]
# # Lesson
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# > fun fact: every repeating number is a factor of 9
# >   (if i understood what the beard-man said)
#
# ![image-3.png](attachment:image-3.png)
#
# > what if i get a repeating 9?
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# let's convert USD to CAD
#
# $$
# \frac{
#      1 \text{ USD}
#     }{
#      1.42 \text{ CAD}
#     }
# =
# \frac{
#      x \text{ USD}
#     }{
#      \text{value} \text{ CAD}
#     }
# $$
#
# or
#
# $$
# \frac{
#      1 \text{ USD}
#     }{
#      1.42 \text{ CAD}
#     }
# =
# \frac{
#      \text{value} \text{ USD}
#     }{
#      x \text{ CAD}
#     }
# $$

# %% [markdown]
# # Code

# %%
# Put a zero in for the unknown value
usd = 1
cad = 1.42
n = 4 # usd
d = 0 # cad

# Do not edit under this line

if n==0:
    answer = d * usd / cad
    print(f"{d} CAD = {answer} USD")

if d==0:
    answer = n * cad / usd
    print(f"{n} USD = {answer} CAD")
# Out:
# 4 USD = 5.68 CAD
